# %%
# 1. Crear la estructura de carpetas
# !mkdir -p data notebooks

# 2. Crear el archivo .gitkeep para que Git detecte la carpeta data
# !touch data/.gitkeep

# 3. Mover tu notebook a la carpeta notebooks
# Asegúrate de que el nombre coincide exactamente con el archivo que ves en tu explorador de archivos
# !mv PROYECTO_REAL_ETL.ipynb notebooks/
# Out:
# mv: cannot stat 'PROYECTO_REAL_ETL.ipynb': No such file or directory

# %%
# !ls -R
# Out:
# .:
# data  notebooks  sample_data
#
# ./data:
#
# ./notebooks:
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# Inicializar y conectar
# !git init
# !git remote add origin https://github.com/arroyolobojoe-spec/etl-adventureworks-pipeline.git
# Ignora si dice "remote origin already exists"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# Buscar el archivo donde sea que esté
# !find . -name "*.ipynb"

# Mover el archivo a la carpeta notebooks (si se llama distinto, avísame)
# !mv PROYECTO_REAL_ETL.ipynb notebooks/
# Out:
# mv: cannot stat 'PROYECTO_REAL_ETL.ipynb': No such file or directory
